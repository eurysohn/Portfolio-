# %%
# 하기 코드실행에 필요한 라이브러리들을 가져오는 코드입니다.

import cv2, imutils, re, sys, math
import xlsxwriter, json, os
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
from matplotlib import rcParams
import operator
import heapq
from pathlib import Path

# %%
# 현재의 디렉토리를 확인합니다. 디렉토리를 확인하고 이미지를 가져올 폴더를 선택합니다.

print(os.getcwd())
# Out:
# g:\내 드라이브\code-20220207T014959Z-001\code\data\processed_images\Part2

# %%
# x axis, y axis 를 찾는 함수입니다.
# 이미지의 픽셀중에서 axis일것으로 판단되는 픽셀들을 찾아, 가장 많은 픽셀이 한 직선 위에 있다면 axis 인것으로 특정합니다.
# 
# 변수 설명: 
# filepath: 이미지 파일을 가져올 디렉토리를 설정하는 변수입니다. 
# threshold: 비슷한 색들을 어느정도 수용할 수 있는 RGB 값의 범위를 정합니다. 하얀색의 rgb값은 255,255,255이며 검은색의 rgb 값은 0,0,0 입니다. 인간의 눈으로 보았을 때 255,255,250 도 흰색으로 보이기 때문에 허용될 r, g, b 값의 차이를 선택하는 변수입니다. (기본 10)
# number_of_elements: 검은색~회색 계열의 픽셀을 가장 많이 갖고 있는 직선의 개수를 선택하는 변수 (기본 100)
def axisreader(filepath, threshold = None, number_of_elements = None):

    if filepath is None:
        return None, None
    
    if threshold is None:
        threshold = 10
        
    if number_of_elements is None:
        number_of_elements = 100
    
    # img를 불러옵니다.
    img = cv2.imread(filepath)

    height, width, channels = img.shape
    crop_img = img[3:height-3, 3:width-3]

# 각각 RGB 값의 value 가 +- 1 인 threshold 만들기.

    higher_threshold = np.median(crop_img, axis=2) + threshold
    lower_threshold = np.median(crop_img, axis=2) - threshold

# RGB 중에 한 값이라도 250을 넘어가면 전부 255,255,255로 처리하고, 0보다 작거나 같은 값은 0,0,0으로 처리해라.
    np.place(higher_threshold, higher_threshold > 250, [255,255,255])
    np.place(lower_threshold, lower_threshold <= 0, [0,0,0])

    higher_threshold = np.rint(higher_threshold).astype(int)
    lower_threshold = np.rint(lower_threshold).astype(int)

    h1 = np.array([higher_threshold, higher_threshold, higher_threshold]).astype(int)
    l1 = np.array([lower_threshold,lower_threshold,lower_threshold]).astype(int)

    h1 = h1.reshape(height-6,width-6,3)
    l1 = l1.reshape(height-6,width-6,3)

# RGB 값이 같거나, threshold 안쪽 범위이거나, white 가 아니라면 1로, 그 외에는 0 으로 처리합니다.

    mask = np.uint8(np.where(((crop_img != 255) & (crop_img == crop_img)) | ((crop_img < h1) & (l1 <= crop_img)) , 1, 0))

# reduce sum으로 각각의 row, column 를 더한 후, 조건을 만족하는 1 값이 가장 많은 row, column 찾습니다.

    col_counts = cv2.reduce(mask, 0, cv2.REDUCE_SUM, dtype=cv2.CV_32SC1)
    row_counts = cv2.reduce(mask, 1, cv2.REDUCE_SUM, dtype=cv2.CV_32SC1)

    col_list = col_counts.flatten().tolist()
    row_list = row_counts.flatten().tolist()

    max_col = max(col_list)
    max_row = max(row_list)

#############################################################################################

    col_set = set(col_list)
    col_list_fromset = list(col_set)

# 이미지 column 중에서 yaxis 일 확률이 높은 픽셀이 많은 상위 n 개 찾기 
    col_list_max = heapq.nlargest(number_of_elements, col_list_fromset)


    col_list_maxnum = []
    for i in col_list_max:
        if i < max(col_list_max)-50:
            continue
        col_list_maxnum.append(i)

    col_list_maxnum_norepeat = []
    for v in col_list_maxnum:
        if v not in col_list_maxnum_norepeat:
            col_list_maxnum_norepeat.append(v)


    col_max_index_listnum = []
    for i in col_list:
        for a in col_list_maxnum_norepeat:
            if i == a:
                x = [index for index in range(
                    len(col_list)) if col_list[index] == i]
                for i in x:
                    col_max_index_listnum.append(i)

    col_max_index_listnum

#############################################################################################
    c1 = round(col_max_index_listnum[0]/3)
    yaxis = (c1, 0, c1, height)
#############################################################################################
    row_set = set(row_list)
    row_list_fromset = list(row_set)

# 이미지 row 중에서 xaxis 일 확률이 높은 픽셀이 많은 상위 n 개 찾기 

    row_list_max = heapq.nlargest(number_of_elements, row_list_fromset)

    row_list_maxnum = []
    for i in row_list_max:
        if i < max(row_list_max)-50:
            continue
        row_list_maxnum.append(i)

    row_list_maxnum_norepeat = []
    for v in row_list_maxnum:
        if v not in row_list_maxnum_norepeat:
            row_list_maxnum_norepeat.append(v)


    row_max_index_listnum = []
    for i in row_list:
        for a in row_list_maxnum_norepeat:
            if i == a:
                x = [index for index in range(len(row_list)) if row_list[index] == i]
                for i in x:
                    row_max_index_listnum.append(i)

    row_max_index_listnum
##############################################################################################
    r1 = round(row_max_index_listnum[-1]/3)
    xaxis = (0, r1, width, r1)


# 선그리기

    cv2.line(crop_img, (width-6 ,round(r1)), (0, round(r1)), color=(0,0,255), thickness=1)
    cv2.line(crop_img, (round(c1),height-6), (round(c1),0), color=(0,0,255), thickness=1)
    
    return xaxis, yaxis

# %%
# 그래프의 값을 받아올 구역을 정하는 bounding box를 정의하는 함수입니다.

def bounding_box(xaxis, yaxis):

    if xaxis is None:
        return None, None

    if yaxis is None:
        return None, None

    if xaxis[1]*(yaxis[3]-yaxis[0]) > yaxis[3]*xaxis[2]*0.5:
        a = yaxis[0], yaxis[1]
        b = yaxis[0], xaxis[1]
        c = xaxis[2]-6, xaxis[1] 
        d = xaxis[2]-6, yaxis[1]

    if xaxis[1]*yaxis[1] < yaxis[3]*xaxis[2]*0.5:
        a = yaxis[0], -yaxis[1]
        b = yaxis[0], xaxis[1]
        c = xaxis[2]-6, xaxis[1] 
        d = xaxis[2]-6, -yaxis[1]

    
    
    return a, b, c, d

# %% [markdown]
# Predicted data 가져오기

# %%
# 사용할 라이브러리 실행하는 코드

import io
import cv2
import requests
import pandas as pd
from PIL import Image
from requests_toolbelt.multipart.encoder import MultipartEncoder

# %%
# line chart 의 data를 수정후 가져오는 함수입니다. filepath 는 이미지가 있는 폴더 위치입니다.

def revised_prediction(filepath):

    

    
    # 엑셀 파일에 저장된 각각의 sheet을 for loop을 통해서 가져옵니다.

    files = os.listdir(filepath)
    os.chdir(filepath)
    for file in files:
        img = cv2.imread(file)
        image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        pilImage = Image.fromarray(image)

        # Convert to JPEG Buffer
        buffered = io.BytesIO()
        pilImage.save(buffered, quality=100, format="JPEG")

        # 데이터셋을 학습된 object detection 모델에 보냅니다.

        # Build multipart form and post request
        m = MultipartEncoder(fields={'file': ("imageToUpload", buffered.getvalue(), "image/jpeg")})

        response = requests.post("https://detect.roboflow.com/line_graph_label/1?api_key=YkTWEru4OpfhWfNyoIIS", data=m, headers={'Content-Type': m.content_type})
        prediction_value = response.json()

        data = pd.read_excel("../../../results/FigureData.xlsx", sheet_name = files.index(file))

        x_text = data.loc[1][1:]
        x_label = data.loc[2]
        y_text = data.loc[3][1:]
        y_label = data.loc[4]
        legends = data.loc[5][1:]


        # 각 축 값의 범위를 계산합니다.
        
        x_label_list =[]
        y_label_list =[]


        for i in range(1,len(y_label)-1):
            try:
                y_label_list.append(float(y_label[i]))
            except ValueError:  
                pass
                
        y_value_range = max(y_label_list)-min(y_label_list)

        for i in range(1,len(x_label)-1):
            try:
                x_label_list.append(float(x_label[i]))
            except ValueError:  
                pass
                
        if len(x_label_list) != 0:
            x_value_range = max(x_label_list)-min(x_label_list)
        else:
            pass
        
        
        # axis reader 함수로 받아온 axes list에서 xaxis, yaxis 값 뽑아내서 재정의하기
        axes = axisreader(file)
        xaxis = axes[0]
        yaxis = axes[1]
        # 0,height
        a = bounding_box(xaxis, yaxis)[0]
        # 0,0
        b = bounding_box(xaxis, yaxis)[1]
        # width,0
        c = bounding_box(xaxis, yaxis)[2]
        # width, height
        d = bounding_box(xaxis, yaxis)[3]
        
        # 각 축의 길이 (축과 data point 위치의 비율을 통해서 data를 찾아내기에 필요함)
        x_axis_length = c[0]-b[0]-20
        y_axis_length = b[1]-a[1]-30

        # 수정한 값을 데이터 프레임으로 저장하기
        
        revised_xvalues = []
        revised_yvalues = []
        revised_class = []
        error = []

        for i in range(0, len(prediction_value['predictions'])):
            revised_xvalues.append((prediction_value['predictions'][i]['x']-b[0])/x_axis_length*x_value_range)
            revised_yvalues.append((b[1]-prediction_value['predictions'][i]['y'])/y_axis_length*y_value_range)
            revised_class.append(prediction_value['predictions'][i]['class'])
            error.append((prediction_value['predictions'][i]['height']/2)/y_axis_length*y_value_range)

        revised_prediction = pd.DataFrame({'class':revised_class,
        'x':revised_xvalues,
        'y':revised_yvalues,
        'error':error})

        chart_format = pd.DataFrame({'legend':legends,
        'x_text':x_text,
        'y_text':y_text})

        revised_prediction = revised_prediction.sort_values(by=['class', 'x'], ascending=[False, True])

        revised_prediction = pd.concat([chart_format,revised_prediction])
        print(revised_prediction)
    return revised_prediction

# %%
revised_prediction('../Part2')
# Out:
#                 legend   x_text    y_text           class         x  \
# Unnamed: 1  Irbesartan      Log  Response             NaN       NaN
# Unnamed: 2         NaN  (mol/L)       (%)             NaN       NaN
# Unnamed: 3         NaN      NaN       NaN             NaN       NaN
# Unnamed: 4         NaN      NaN       NaN             NaN       NaN
# Unnamed: 5         NaN      NaN       NaN             NaN       NaN
# Unnamed: 6         NaN      NaN       NaN             NaN       NaN
# 19                 NaN      NaN       NaN        triangle  0.531153
# 2                  NaN      NaN       NaN        triangle  0.532710
# 6                  NaN      NaN       NaN        triangle  1.038941
# 23                 NaN      NaN       NaN          square  0.124611
# 25                 NaN      NaN       NaN          square  0.224299
# 12                 NaN      NaN       NaN          square  0.328660
# 18                 NaN      NaN       NaN          square  0.425234
# 3                  NaN      NaN       NaN          square  0.526480
# 20                 NaN      NaN       NaN          square  0.529595
# 37                 NaN      NaN       NaN          square  0.630841
# 31                 NaN      NaN       NaN          square  0.632399
# 5                  NaN      NaN       NaN          square  0.733645
# 8                  NaN      NaN       NaN          square  0.733645
# 26                 NaN      NaN       NaN          square  0.836449
# 1                  NaN      NaN       NaN          square  0.934579
# 4                  NaN      NaN       NaN          square  1.037383
# 13                 NaN      NaN       NaN  empty-triangle  0.126168
# 0                  NaN      NaN       NaN  empty-triangle  0.222741
# 30                 NaN      NaN       NaN  empty-triangle  0.224299
# 17                 NaN      NaN       NaN  empty-triangle  0.323988
# 29                 NaN      NaN       NaN  empty-triangle  0.327103
# 33                 NaN      NaN       NaN  empty-triangle  0.420561
# 24                 NaN      NaN       NaN  empty-triangle  0.426791
# 11                 NaN      NaN       NaN  empty-triangle  0.526480
# 27                 NaN      NaN       NaN  empty-triangle  0.531153
# 35                 NaN      NaN       NaN  empty-triangle  0.531153
# 21                 NaN      NaN       NaN  empty-triangle  0.627726
# 32                 NaN      NaN       NaN  empty-triangle  0.630841
# 10                 NaN      NaN       NaN  empty-triangle  0.633956
# 14                 NaN      NaN       NaN  empty-triangle  0.730530
# 28                 NaN      NaN       NaN  empty-triangle  0.733645
# 9                  NaN      NaN       NaN  empty-triangle  0.735202
# 36                 NaN      NaN       NaN  empty-triangle  0.833333
# 22                 NaN      NaN       NaN  empty-triangle  0.836449
# 7                  NaN      NaN       NaN  empty-triangle  0.936137
# 15                 NaN      NaN       NaN  empty-triangle  0.936137
# 16                 NaN      NaN       NaN  empty-triangle  1.037383
# 34                 NaN      NaN       NaN  empty-triangle  1.037383
#
#                     y     error
# Unnamed: 1        NaN       NaN
# Unnamed: 2        NaN       NaN
# Unnamed: 3        NaN       NaN
# Unnamed: 4        NaN       NaN
# Unnamed: 5        NaN       NaN
# Unnamed: 6        NaN       NaN
# 19           2.152318  3.145695
# 2           10.099338  2.814570
# 6           85.927152  3.145695
# 23           0.000000  2.649007
# 25           0.000000  2.317881
# 12           0.662252  2.649007
# 18           0.496689  2.483444
# 3            9.602649  2.649007
# 20           1.490066  2.814570
# 37           5.960265  2.980132
# 31          31.125828  3.642384
# 5           24.006623  2.814570
# 8           61.920530  2.980132
# 26          83.443709  3.311258
# 1           85.430464  2.980132
# 4           86.258278  3.476821
# 13           0.165563  2.814570
# 0           14.900662  3.311258
# 30           0.827815  2.483444
# 17          38.576159  3.476821
# 29           1.158940  2.483444
# 33          60.596026  3.311258
# 24           0.331126  2.317881
# 11          70.198675  3.642384
# 27           9.933775  2.649007
# 35           1.158940  2.483444
# 21          77.317881  3.476821
# 32          30.463576  3.642384
# 10           6.125828  2.814570
# 14          61.920530  2.980132
# 28          24.006623  2.814570
# 9           78.807947  3.973510
# 36          83.278146  2.814570
# 22          50.827815  3.145695
# 7           85.430464  2.980132
# 15          68.874172  2.317881
# 16          77.814570  2.980132
# 34          85.761589  3.642384
#            legend x_text         y_text         class          x   y  error
# Unnamed: 1  1,000   Time     Fimasartan           NaN        NaN NaN    NaN
# Unnamed: 2    NaN    (h)  concentration           NaN        NaN NaN    NaN
# Unnamed: 3    NaN    NaN            NaN           NaN        NaN NaN    NaN
# Unnamed: 4    NaN    NaN            NaN           NaN        NaN NaN    NaN
# Unnamed: 5    NaN    NaN            NaN           NaN        NaN NaN    NaN
# 2             NaN    NaN            NaN  empty-circle  13.268041 NaN    NaN
# 1             NaN    NaN            NaN  empty-circle  14.335052 NaN    NaN
# 0             NaN    NaN            NaN  empty-circle  16.701031 NaN    NaN
# 4             NaN    NaN            NaN  empty-circle  23.659794 NaN    NaN
# 3             NaN    NaN            NaN  empty-circle  37.716495 NaN    NaN
#            legend         x_text      y_text             class         x   y  \
# Unnamed: 1      *            ARB  Inhibition               NaN       NaN NaN
# Unnamed: 2    NaN  concentration         (%)               NaN       NaN NaN
# Unnamed: 3    NaN           [Log         NaN               NaN       NaN NaN
# Unnamed: 4    NaN             M]         NaN               NaN       NaN NaN
# Unnamed: 5    NaN            NaN         NaN               NaN       NaN NaN
# Unnamed: 6    NaN            NaN         NaN               NaN       NaN NaN
# Unnamed: 7    NaN            NaN         NaN               NaN       NaN NaN
# Unnamed: 8    NaN            NaN         NaN               NaN       NaN NaN
# 40            NaN            NaN         NaN          triangle  4.445187 NaN
# 11            NaN            NaN         NaN          triangle  5.409091 NaN
# 13            NaN            NaN         NaN            square  4.445187 NaN
# 21            NaN            NaN         NaN            square  5.399733 NaN
# 9             NaN            NaN         NaN            square  5.418449 NaN
# 32            NaN            NaN         NaN           rhombus  5.427807 NaN
# 42            NaN            NaN         NaN  inverse-triangle  2.545455 NaN
# 17            NaN            NaN         NaN  inverse-triangle  3.481283 NaN
# 29            NaN            NaN         NaN  inverse-triangle  3.490642 NaN
# 26            NaN            NaN         NaN  inverse-triangle  4.445187 NaN
# 6             NaN            NaN         NaN  inverse-triangle  5.399733 NaN
# 5             NaN            NaN         NaN  inverse-triangle  5.409091 NaN
# 12            NaN            NaN         NaN  inverse-triangle  5.409091 NaN
# 43            NaN            NaN         NaN    empty-triangle  1.553476 NaN
# 39            NaN            NaN         NaN    empty-triangle  1.590909 NaN
# 34            NaN            NaN         NaN    empty-triangle  2.536096 NaN
# 22            NaN            NaN         NaN    empty-triangle  2.545455 NaN
# 24            NaN            NaN         NaN    empty-triangle  3.481283 NaN
# 16            NaN            NaN         NaN    empty-triangle  3.490642 NaN
# 37            NaN            NaN         NaN    empty-triangle  3.490642 NaN
# 35            NaN            NaN         NaN    empty-triangle  3.500000 NaN
# 46            NaN            NaN         NaN    empty-triangle  3.500000 NaN
# 38            NaN            NaN         NaN    empty-triangle  4.417112 NaN
# 28            NaN            NaN         NaN    empty-triangle  4.435829 NaN
# 33            NaN            NaN         NaN    empty-triangle  4.435829 NaN
# 2             NaN            NaN         NaN    empty-triangle  4.445187 NaN
# 4             NaN            NaN         NaN    empty-triangle  4.445187 NaN
# 19            NaN            NaN         NaN    empty-triangle  4.445187 NaN
# 14            NaN            NaN         NaN    empty-triangle  5.381016 NaN
# 15            NaN            NaN         NaN    empty-triangle  5.381016 NaN
# 8             NaN            NaN         NaN    empty-triangle  5.390374 NaN
# 36            NaN            NaN         NaN    empty-triangle  5.399733 NaN
# 18            NaN            NaN         NaN    empty-triangle  5.418449 NaN
# 0             NaN            NaN         NaN    empty-triangle  6.363636 NaN
# 20            NaN            NaN         NaN    empty-triangle  6.363636 NaN
# 41            NaN            NaN         NaN    empty-triangle  6.363636 NaN
# 25            NaN            NaN         NaN      empty-circle  1.562834 NaN
# 27            NaN            NaN         NaN      empty-circle  1.590909 NaN
# 45            NaN            NaN         NaN      empty-circle  2.386364 NaN
# 23            NaN            NaN         NaN      empty-circle  2.508021 NaN
# 30            NaN            NaN         NaN      empty-circle  2.564171 NaN
# 47            NaN            NaN         NaN      empty-circle  2.573529 NaN
# 10            NaN            NaN         NaN      empty-circle  3.481283 NaN
# 31            NaN            NaN         NaN      empty-circle  3.509358 NaN
# 1             NaN            NaN         NaN      empty-circle  4.426471 NaN
# 44            NaN            NaN         NaN      empty-circle  5.371658 NaN
# 3             NaN            NaN         NaN      empty-circle  5.381016 NaN
# 7             NaN            NaN         NaN      empty-circle  6.363636 NaN
#
#             error
# Unnamed: 1    NaN
# Unnamed: 2    NaN
# Unnamed: 3    NaN
# Unnamed: 4    NaN
# Unnamed: 5    NaN
# Unnamed: 6    NaN
# Unnamed: 7    NaN
# Unnamed: 8    NaN
# 40            NaN
# 11            NaN
# 13            NaN
# 21            NaN
# 9             NaN
# 32            NaN
# 42            NaN
# 17            NaN
# 29            NaN
# 26            NaN
# 6             NaN
# 5             NaN
# 12            NaN
# 43            NaN
# 39            NaN
# 34            NaN
# 22            NaN
# 24            NaN
# 16            NaN
# 37            NaN
# 35            NaN
# 46            NaN
# 38            NaN
# 28            NaN
# 33            NaN
# 2             NaN
# 4             NaN
# 19            NaN
# 14            NaN
# 15            NaN
# 8             NaN
# 36            NaN
# 18            NaN
# 0             NaN
# 20            NaN
# 41            NaN
# 25            NaN
# 27            NaN
# 45            NaN
# 23            NaN
# 30            NaN
# 47            NaN
# 10            NaN
# 31            NaN
# 1             NaN
# 44            NaN
# 3             NaN
# 7             NaN
#            legend         x_text       y_text             class         x  \
# Unnamed: 1    NaN            Ang  Contraction               NaN       NaN
# Unnamed: 2    NaN             II          (%)               NaN       NaN
# Unnamed: 3    NaN  Concentration          NaN               NaN       NaN
# Unnamed: 4    NaN           [Log          NaN               NaN       NaN
# Unnamed: 5    NaN             M]          NaN               NaN       NaN
# Unnamed: 6    NaN            NaN          NaN               NaN       NaN
# Unnamed: 7    NaN            NaN          NaN               NaN       NaN
# Unnamed: 8    NaN            NaN          NaN               NaN       NaN
# 13            NaN            NaN          NaN  inverse-triangle  0.942136
# 21            NaN            NaN          NaN  inverse-triangle  1.335312
# 14            NaN            NaN          NaN  inverse-triangle  1.780415
# 30            NaN            NaN          NaN  inverse-triangle  2.188427
# 6             NaN            NaN          NaN  inverse-triangle  2.633531
# 9             NaN            NaN          NaN  inverse-triangle  2.633531
# 18            NaN            NaN          NaN  inverse-triangle  3.486647
# 25            NaN            NaN          NaN  inverse-triangle  3.894659
# 16            NaN            NaN          NaN    empty-triangle  0.949555
# 8             NaN            NaN          NaN    empty-triangle  1.787834
# 20            NaN            NaN          NaN    empty-triangle  2.195846
# 0             NaN            NaN          NaN    empty-triangle  2.633531
# 5             NaN            NaN          NaN    empty-triangle  3.041543
# 29            NaN            NaN          NaN      empty-circle  0.927300
# 11            NaN            NaN          NaN      empty-circle  1.335312
# 10            NaN            NaN          NaN      empty-circle  1.772997
# 1             NaN            NaN          NaN      empty-circle  1.780415
# 7             NaN            NaN          NaN      empty-circle  1.795252
# 28            NaN            NaN          NaN      empty-circle  2.188427
# 32            NaN            NaN          NaN      empty-circle  2.188427
# 31            NaN            NaN          NaN      empty-circle  2.203264
# 26            NaN            NaN          NaN      empty-circle  2.611276
# 2             NaN            NaN          NaN      empty-circle  3.041543
# 4             NaN            NaN          NaN      empty-circle  3.048961
# 23            NaN            NaN          NaN      empty-circle  3.056380
# 15            NaN            NaN          NaN      empty-circle  3.479228
# 27            NaN            NaN          NaN      empty-circle  3.887240
# 17            NaN            NaN          NaN            circle  2.188427
# 22            NaN            NaN          NaN            circle  2.633531
# 12            NaN            NaN          NaN            circle  3.041543
# 3             NaN            NaN          NaN            circle  3.494065
# 19            NaN            NaN          NaN            circle  3.902077
# 24            NaN            NaN          NaN            circle  4.339763
#
#                      y      error
# Unnamed: 1         NaN        NaN
# Unnamed: 2         NaN        NaN
# Unnamed: 3         NaN        NaN
# Unnamed: 4         NaN        NaN
# Unnamed: 5         NaN        NaN
# Unnamed: 6         NaN        NaN
# Unnamed: 7         NaN        NaN
# Unnamed: 8         NaN        NaN
# 13            0.538922   2.694611
# 21            0.718563   2.514970
# 14            7.005988   3.413174
# 30           43.473054   9.341317
# 6            15.808383   6.826347
# 9            81.736527   4.491018
# 18          101.137725   4.131737
# 25          101.317365   2.874251
# 16           18.323353   4.311377
# 8            87.125749   3.053892
# 20           96.287425   3.233533
# 0            97.724551   3.592814
# 5            97.544910   4.131737
# 29           16.526946   3.592814
# 11           58.023952   3.772455
# 10           86.946108   3.233533
# 1             0.359281   2.874251
# 7            10.239521   3.772455
# 28           45.449102  10.958084
# 32           96.467066   3.413174
# 31            8.263473   3.592814
# 26           56.047904   7.185629
# 2            97.724551   4.311377
# 4            86.227545   3.592814
# 23           62.874251   5.029940
# 15          101.137725   4.131737
# 27          103.652695   4.850299
# 17            0.359281   2.874251
# 22           14.910180   7.365269
# 12           61.976048   5.928144
# 3            89.820359   2.874251
# 19          101.137725   3.413174
# 24          108.143713   3.952096
#                   legend x_text y_text             class   x   y  error
# Unnamed: 1            of    NaN    NaN               NaN NaN NaN    NaN
# Unnamed: 2  atorvastatin    NaN    NaN               NaN NaN NaN    NaN
# Unnamed: 3     (ng-mL-1)    NaN    NaN               NaN NaN NaN    NaN
# 0                    NaN    NaN    NaN  inverse-triangle NaN NaN    NaN
# 2                    NaN    NaN    NaN    empty-triangle NaN NaN    NaN
# 4                    NaN    NaN    NaN    empty-triangle NaN NaN    NaN
# 1                    NaN    NaN    NaN      empty-circle NaN NaN    NaN
# 3                    NaN    NaN    NaN      empty-circle NaN NaN    NaN
# 5                    NaN    NaN    NaN      empty-circle NaN NaN    NaN
# 6                    NaN    NaN    NaN      empty-circle NaN NaN    NaN
#            legend x_text  y_text   class         x          y     error
# Unnamed: 1      *   Time  Change     NaN       NaN        NaN       NaN
# Unnamed: 2      *    (h)      of     NaN       NaN        NaN       NaN
# Unnamed: 3    NaN    NaN     MAP     NaN       NaN        NaN       NaN
# Unnamed: 4    NaN    NaN     (%)     NaN       NaN        NaN       NaN
# Unnamed: 5    NaN    NaN     NaN     NaN       NaN        NaN       NaN
# ...           ...    ...     ...     ...       ...        ...       ...
# 74            NaN    NaN     NaN  circle  5.725434  30.152905  2.140673
# 76            NaN    NaN     NaN  circle  6.150289  30.275229  2.018349
# 12            NaN    NaN     NaN  circle  6.544798  28.685015  1.529052
# 71            NaN    NaN     NaN  circle  6.929191  29.602446  1.467890
# 60            NaN    NaN     NaN  circle  7.343931  29.969419  1.957187
#
# [91 rows x 7 columns]
#            legend x_text  y_text   class         x          y     error
# Unnamed: 1    NaN   Time  Change     NaN       NaN        NaN       NaN
# Unnamed: 2    NaN    (h)      of     NaN       NaN        NaN       NaN
# Unnamed: 3    NaN    NaN     MAP     NaN       NaN        NaN       NaN
# Unnamed: 4    NaN    NaN     (%)     NaN       NaN        NaN       NaN
# Unnamed: 5    NaN    NaN     NaN     NaN       NaN        NaN       NaN
# ...           ...    ...     ...     ...       ...        ...       ...
# 19            NaN    NaN     NaN  circle  4.552632  39.570552  1.073620
# 40            NaN    NaN     NaN  circle  4.885965  38.957055  0.920245
# 33            NaN    NaN     NaN  circle  5.245614  38.957055  1.073620
# 12            NaN    NaN     NaN  circle  5.254386  31.441718  1.533742
# 23            NaN    NaN     NaN  circle  5.578947  40.184049  1.380368
#
# [68 rows x 7 columns]
#                legend     x_text y_text             class         x    y  \
# Unnamed: 1        SHR      Weeks     HR               NaN       NaN  NaN
# Unnamed: 2  SHR + HDZ         of  (bpm)               NaN       NaN  NaN
# Unnamed: 3        NaN  treatment    (b)               NaN       NaN  NaN
# Unnamed: 4        NaN        NaN    NaN               NaN       NaN  NaN
# Unnamed: 5        NaN        NaN    NaN               NaN       NaN  NaN
# Unnamed: 6        NaN        NaN    NaN               NaN       NaN  NaN
# Unnamed: 7        NaN        NaN    NaN               NaN       NaN  NaN
# 20                NaN        NaN    NaN          triangle  0.603448  0.0
# 5                 NaN        NaN    NaN          triangle  0.752351  0.0
# 7                 NaN        NaN    NaN          triangle  1.434169  0.0
# 14                NaN        NaN    NaN          triangle  1.449843  0.0
# 26                NaN        NaN    NaN          triangle  2.233542  0.0
# 22                NaN        NaN    NaN          triangle  3.111285  0.0
# 0                 NaN        NaN    NaN            square  0.603448  0.0
# 1                 NaN        NaN    NaN            square  0.744514  0.0
# 3                 NaN        NaN    NaN            square  0.744514  0.0
# 2                 NaN        NaN    NaN            square  1.410658  0.0
# 21                NaN        NaN    NaN            square  1.442006  0.0
# 11                NaN        NaN    NaN            square  2.264890  0.0
# 24                NaN        NaN    NaN            square  2.264890  0.0
# 16                NaN        NaN    NaN            square  3.103448  0.0
# 13                NaN        NaN    NaN            square  3.111285  0.0
# 4                 NaN        NaN    NaN            square  3.926332  0.0
# 12                NaN        NaN    NaN            square  3.934169  0.0
# 18                NaN        NaN    NaN            square  4.788401  0.0
# 19                NaN        NaN    NaN  inverse-triangle  2.272727  0.0
# 25                NaN        NaN    NaN  inverse-triangle  3.095611  0.0
# 6                 NaN        NaN    NaN  inverse-triangle  3.942006  0.0
# 23                NaN        NaN    NaN  inverse-triangle  4.780564  0.0
# 17                NaN        NaN    NaN    empty-triangle  0.587774  0.0
# 15                NaN        NaN    NaN    empty-triangle  0.744514  0.0
# 9                 NaN        NaN    NaN    empty-triangle  1.426332  0.0
# 8                 NaN        NaN    NaN    empty-triangle  1.442006  0.0
# 10                NaN        NaN    NaN    empty-triangle  3.111285  0.0
#
#             error
# Unnamed: 1    NaN
# Unnamed: 2    NaN
# Unnamed: 3    NaN
# Unnamed: 4    NaN
# Unnamed: 5    NaN
# Unnamed: 6    NaN
# Unnamed: 7    NaN
# 20            0.0
# 5             0.0
# 7             0.0
# 14            0.0
# 26            0.0
# 22            0.0
# 0             0.0
# 1             0.0
# 3             0.0
# 2             0.0
# 21            0.0
# 11            0.0
# 24            0.0
# 16            0.0
# 13            0.0
# 4             0.0
# 12            0.0
# 18            0.0
# 19            0.0
# 25            0.0
# 6             0.0
# 23            0.0
# 17            0.0
# 15            0.0
# 9             0.0
# 8             0.0
# 10            0.0
#               legend x_text         y_text           class   x          y  \
# Unnamed: 1   Control    NaN  Catecholamine             NaN NaN        NaN
# Unnamed: 2       NaN    NaN      Secretion             NaN NaN        NaN
# Unnamed: 3       NaN    NaN            (%)             NaN NaN        NaN
# Unnamed: 4       NaN    NaN           DMPP             NaN NaN        NaN
# Unnamed: 5       NaN    NaN            NaN             NaN NaN        NaN
# Unnamed: 6       NaN    NaN            NaN             NaN NaN        NaN
# Unnamed: 7       NaN    NaN            NaN             NaN NaN        NaN
# Unnamed: 8       NaN    NaN            NaN             NaN NaN        NaN
# Unnamed: 9       NaN    NaN            NaN             NaN NaN        NaN
# Unnamed: 10      NaN    NaN            NaN             NaN NaN        NaN
# Unnamed: 11      NaN    NaN            NaN             NaN NaN        NaN
# 0                NaN    NaN            NaN          square NaN  11.186441
# 1                NaN    NaN            NaN  empty-triangle NaN  10.550847
# 3                NaN    NaN            NaN  empty-triangle NaN  -0.508475
# 4                NaN    NaN            NaN  empty-triangle NaN  29.618644
# 2                NaN    NaN            NaN    empty-circle NaN  -0.635593
#
#                  error
# Unnamed: 1         NaN
# Unnamed: 2         NaN
# Unnamed: 3         NaN
# Unnamed: 4         NaN
# Unnamed: 5         NaN
# Unnamed: 6         NaN
# Unnamed: 7         NaN
# Unnamed: 8         NaN
# Unnamed: 9         NaN
# Unnamed: 10        NaN
# Unnamed: 11        NaN
# 0             2.033898
# 1             1.652542
# 3             1.525424
# 4            16.398305
# 2             1.398305
#                      legend x_text          y_text           class   x   y  \
# Unnamed: 1  20 cells/0.5mm2    NaN          Number             NaN NaN NaN
# Unnamed: 2              NaN    NaN              of             NaN NaN NaN
# Unnamed: 3              NaN    NaN  F4/80-positive             NaN NaN NaN
# 0                       NaN    NaN             NaN  empty-triangle NaN NaN
#
#             error
# Unnamed: 1    NaN
# Unnamed: 2    NaN
# Unnamed: 3    NaN
# 0             NaN
#               legend x_text         y_text         class   x         y  \
# Unnamed: 1   Control    NaN  Catecholamine           NaN NaN       NaN
# Unnamed: 2       NaN    NaN      Secretion           NaN NaN       NaN
# Unnamed: 3       NaN    NaN            (%)           NaN NaN       NaN
# Unnamed: 4       NaN    NaN      McN-A-343           NaN NaN       NaN
# Unnamed: 5       NaN    NaN            NaN           NaN NaN       NaN
# Unnamed: 6       NaN    NaN            NaN           NaN NaN       NaN
# Unnamed: 7       NaN    NaN            NaN           NaN NaN       NaN
# Unnamed: 8       NaN    NaN            NaN           NaN NaN       NaN
# Unnamed: 9       NaN    NaN            NaN           NaN NaN       NaN
# Unnamed: 10      NaN    NaN            NaN           NaN NaN       NaN
# Unnamed: 11      NaN    NaN            NaN           NaN NaN       NaN
# Unnamed: 12      NaN    NaN            NaN           NaN NaN       NaN
# 0                NaN    NaN            NaN  empty-circle NaN  0.283286
#
#                 error
# Unnamed: 1        NaN
# Unnamed: 2        NaN
# Unnamed: 3        NaN
# Unnamed: 4        NaN
# Unnamed: 5        NaN
# Unnamed: 6        NaN
# Unnamed: 7        NaN
# Unnamed: 8        NaN
# Unnamed: 9        NaN
# Unnamed: 10       NaN
# Unnamed: 11       NaN
# Unnamed: 12       NaN
# 0            1.416431
#            legend x_text   y_text           class   x         y     error
# Unnamed: 1    NaN    NaN    Nox1/             NaN NaN       NaN       NaN
# Unnamed: 2    NaN    NaN  B-actin             NaN NaN       NaN       NaN
# Unnamed: 3    NaN    NaN   (fold)             NaN NaN       NaN       NaN
# Unnamed: 4    NaN    NaN      NaN             NaN NaN       NaN       NaN
# Unnamed: 5    NaN    NaN      NaN             NaN NaN       NaN       NaN
# 2             NaN    NaN      NaN        triangle NaN  0.931193  0.142202
# 0             NaN    NaN      NaN          square NaN  0.926606  0.137615
# 1             NaN    NaN      NaN  empty-triangle NaN  0.922018  0.151376
#            legend x_text   y_text           class   x         y     error
# Unnamed: 1    Los    NaN    (fold             NaN NaN       NaN       NaN
# Unnamed: 2    NaN    NaN      ACE             NaN NaN       NaN       NaN
# Unnamed: 3    NaN    NaN     mRNA             NaN NaN       NaN       NaN
# Unnamed: 4    NaN    NaN  change)             NaN NaN       NaN       NaN
# 3             NaN    NaN      NaN        triangle NaN  0.370968  0.034050
# 4             NaN    NaN      NaN        triangle NaN  0.686380  0.066308
# 1             NaN    NaN      NaN          square NaN  0.854839  0.059140
# 2             NaN    NaN      NaN          square NaN  0.238351  0.030466
# 8             NaN    NaN      NaN          square NaN  0.270609  0.026882
# 9             NaN    NaN      NaN          square NaN  0.689964  0.055556
# 11            NaN    NaN      NaN          square NaN  0.188172  0.030466
# 12            NaN    NaN      NaN          square NaN  0.168459  0.035842
# 16            NaN    NaN      NaN          square NaN  0.369176  0.035842
# 0             NaN    NaN      NaN  empty-triangle NaN  0.557348  0.037634
# 5             NaN    NaN      NaN  empty-triangle NaN  0.220430  0.041219
# 6             NaN    NaN      NaN  empty-triangle NaN  0.164875  0.035842
# 7             NaN    NaN      NaN  empty-triangle NaN  0.849462  0.057348
# 10            NaN    NaN      NaN  empty-triangle NaN  0.458781  0.035842
# 13            NaN    NaN      NaN  empty-triangle NaN  0.259857  0.026882
# 14            NaN    NaN      NaN  empty-triangle NaN  0.688172  0.050179
# 15            NaN    NaN      NaN  empty-triangle NaN  0.618280  0.034050
# 17            NaN    NaN      NaN  empty-triangle NaN  0.754480  0.019713
# 18            NaN    NaN      NaN    empty-circle NaN -0.080645  0.030466
#            legend x_text    y_text           class   x         y    error
# Unnamed: 1    NaN    NaN  Relative             NaN NaN       NaN      NaN
# Unnamed: 2    NaN    NaN      HO-1             NaN NaN       NaN      NaN
# Unnamed: 3    NaN    NaN      mRNA             NaN NaN       NaN      NaN
# Unnamed: 4    NaN    NaN     level             NaN NaN       NaN      NaN
# Unnamed: 5    NaN    NaN       NaN             NaN NaN       NaN      NaN
# 0             NaN    NaN       NaN  empty-triangle NaN  1.301802  0.09009
#            legend x_text    y_text           class   x         y    error
# Unnamed: 1    NaN    NaN  Relative             NaN NaN       NaN      NaN
# Unnamed: 2    NaN    NaN      HO-1             NaN NaN       NaN      NaN
# Unnamed: 3    NaN    NaN      mRNA             NaN NaN       NaN      NaN
# Unnamed: 4    NaN    NaN     level             NaN NaN       NaN      NaN
# Unnamed: 5    NaN    NaN       NaN             NaN NaN       NaN      NaN
# 0             NaN    NaN       NaN  empty-triangle NaN  1.301802  0.09009

# %% [markdown]
# Predicted value 확인

# %%
# data extraction 을 위한 data point object detection 이 잘 이뤄졌는지 확인을 하기 위한 함수

# 이미지 위치 넣기 (폴더 아니고 확인할 이미지 한개의 주소)
img = cv2.imread("../data/processed_images/Part2/fig 3.PNG")
image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
pilImage = Image.fromarray(image)

# Convert to JPEG Buffer
buffered = io.BytesIO()
pilImage.save(buffered, quality=100, format="JPEG")

# Build multipart form and post request
m = MultipartEncoder(fields={'file': ("imageToUpload", buffered.getvalue(), "image/jpeg")})

response = requests.post("https://detect.roboflow.com/line_graph_label/1?api_key=YkTWEru4OpfhWfNyoIIS", data=m, headers={'Content-Type': m.content_type})
prediction_value = response.json()

for i in range(0, len(prediction_value['predictions'])):
    cv2.circle(img, (int(prediction_value['predictions'][i]['x']),int(prediction_value['predictions'][i]['y'])), 10, (255,0,0))

cv2.imshow('check', img)
cv2.waitKey(),
cv2.destroyAllWindows()
